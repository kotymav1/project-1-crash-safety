# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import geoviews as gv
import requests
import hvplot.pandas
from geoviews import opts

# %% [markdown]
# ## Data Cleaning

# %%
raw_data_path = ("../Resources/Crash_Reporting_-_Drivers_Data.csv")
raw_data_df = pd.read_csv(raw_data_path, dtype=str, header=0, low_memory=False, delimiter=',')

# Splitting Date/Time into two separate columns
split_data = raw_data_df['Crash Date/Time'].str.split(' ', n=1, expand=True)
raw_data_df['Date'] = split_data[0]
raw_data_df['Time'] = split_data[1]

# Converting Injury Severity to number values
severity_scale = {
    'NO APPARENT INJURY': 0,
    'POSSIBLE INJURY': 1,
    'SUSPECTED MINOR INJURY': 2,
    'SUSPECTED SERIOUS INJURY': 3,
    'FATAL INJURY': 4
}
raw_data_df['Injury Severity Scale'] = raw_data_df['Injury Severity'].map(severity_scale)

# Ensuring specific columns are numerical data types
raw_data_df['Injury Severity Scale'] = pd.to_numeric(raw_data_df['Injury Severity Scale'], errors='coerce').fillna(0).astype(int)
raw_data_df['Speed Limit'] = pd.to_numeric(raw_data_df['Speed Limit'], errors='coerce').fillna(0).astype(int)
raw_data_df['Latitude'] = pd.to_numeric(raw_data_df['Latitude'], errors='coerce').fillna(0).astype(float)
raw_data_df['Longitude'] = pd.to_numeric(raw_data_df['Longitude'], errors='coerce').fillna(0).astype(float)




# Display raw data
raw_data_df.head()
# Out:
#   Report Number Local Case Number                Agency Name  \
# 0   MCP3170003V         240000438   Montgomery County Police
# 1   MCP3254003K         230072050   Montgomery County Police
# 2    EJ7887003Q         230074270  Gaithersburg Police Depar
# 3   MCP2674004J         230064598   Montgomery County Police
# 4   MCP25280008         230067019   Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time        Route Type  \
# 0  Property Damage Crash  01/03/2024 02:55:00 PM               NaN
# 1           Injury Crash  12/16/2023 12:36:00 PM  Maryland (State)
# 2           Injury Crash  12/29/2023 12:00:00 PM  Maryland (State)
# 3  Property Damage Crash  11/05/2023 09:07:00 PM  Maryland (State)
# 4  Property Damage Crash  11/18/2023 12:40:00 AM  Maryland (State)
#
#           Road Name Cross-Street Type Cross-Street Name  \
# 0               NaN               NaN               NaN
# 1     GERMANTOWN RD            County    MIDDLEBROOK RD
# 2  GREAT SENECA HWY      Municipality    KENTLANDS BLVD
# 3      WOODFIELD RD            County    GLENDALOUGH RD
# 4     CLARKSBURG RD  Maryland (State)     CLARKSBURG RD
#
#             Off-Road Description  ... Vehicle Year Vehicle Make Vehicle Model  \
# 0  IN FRONT OF 18900 BIRDSEYE DR  ...         2017        LEXUS           SUV
# 1                            NaN  ...         2010         TOYT         PRIUS
# 2                            NaN  ...         2021       SUBARU     FORRESTER
# 3                            NaN  ...         2019        DODGE       CHARGER
# 4                            NaN  ...         2014       NISSAN         ROGUE
#
#   Equipment Problems   Latitude  Longitude                     Location  \
# 0          NO MISUSE  39.165005 -77.249310     (39.16500483, -77.24931)
# 1          NO MISUSE  39.178776 -77.267190  (39.17877577, -77.26718974)
# 2          NO MISUSE  39.123574 -77.231769    (39.12357374, -77.231769)
# 3          NO MISUSE  39.211742 -77.171461  (39.21174219, -77.17146065)
# 4                NaN  39.228915 -77.289091  (39.22891483, -77.28909117)
#
#          Date         Time Injury Severity Scale
# 0  01/03/2024  02:55:00 PM                     0
# 1  12/16/2023  12:36:00 PM                     0
# 2  12/29/2023  12:00:00 PM                     2
# 3  11/05/2023  09:07:00 PM                     0
# 4  11/18/2023  12:40:00 AM                     0
#
# [5 rows x 46 columns]

# %%
raw_data_df.dtypes['Latitude']
# Out:
# dtype('float64')

# %%
environment_data_df = raw_data_df[['Injury Severity','Injury Severity Scale','Date', 'Time', 'Speed Limit', 'Light', 'Traffic Control', 'Driver At Fault' ,'Latitude', 'Longitude' ]]

environment_data_df.head()
# Out:
#           Injury Severity  Injury Severity Scale        Date         Time  \
# 0      NO APPARENT INJURY                      0  01/03/2024  02:55:00 PM
# 1      NO APPARENT INJURY                      0  12/16/2023  12:36:00 PM
# 2  SUSPECTED MINOR INJURY                      2  12/29/2023  12:00:00 PM
# 3      NO APPARENT INJURY                      0  11/05/2023  09:07:00 PM
# 4      NO APPARENT INJURY                      0  11/18/2023  12:40:00 AM
#
#    Speed Limit           Light Traffic Control Driver At Fault   Latitude  \
# 0            0        DAYLIGHT     NO CONTROLS             Yes  39.165005
# 1           35        DAYLIGHT  TRAFFIC SIGNAL              No  39.178776
# 2           35        DAYLIGHT  TRAFFIC SIGNAL              No  39.123574
# 3           40  DARK LIGHTS ON     NO CONTROLS              No  39.211742
# 4           20  DARK LIGHTS ON      YIELD SIGN             Yes  39.228915
#
#    Longitude
# 0 -77.249310
# 1 -77.267190
# 2 -77.231769
# 3 -77.171461
# 4 -77.289091

# %%
# Exporting environment_data_df to new CSV

environment_data_df.to_csv('../Resources/environment_data.csv', index=False)

# %% [markdown]
# ## Injury Severity Exploration

# %% [markdown]
# ### Fatal Injuries

# %%
# Isolating Fatal Injuries

fatal_injuries_df = environment_data_df[environment_data_df['Injury Severity Scale'] == 4]

fatal_injuries_df.head()
# Out:
#      Injury Severity  Injury Severity Scale        Date         Time  \
# 20      FATAL INJURY                      4  10/28/2023  12:15:00 PM
# 86      FATAL INJURY                      4  05/21/2023  03:04:00 PM
# 2540    FATAL INJURY                      4  07/20/2023  09:32:00 PM
# 4628    FATAL INJURY                      4  07/29/2023  05:49:00 AM
# 4793    FATAL INJURY                      4  09/01/2023  01:09:00 AM
#
#       Speed Limit                     Light Traffic Control Driver At Fault  \
# 20             30                  DAYLIGHT      YIELD SIGN             Yes
# 86             50                  DAYLIGHT             NaN             Yes
# 2540           40  DARK -- UNKNOWN LIGHTING     NO CONTROLS             Yes
# 4628           45                      DAWN             NaN             Yes
# 4793           35            DARK LIGHTS ON     NO CONTROLS             Yes
#
#        Latitude  Longitude
# 20    39.122468 -76.926338
# 86    39.153050 -77.141618
# 2540  39.161663 -77.419153
# 4628  39.071903 -77.109592
# 4793  38.994862 -77.043648
